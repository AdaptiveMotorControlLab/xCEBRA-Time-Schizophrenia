# %%
from nilearn.image import resample_to_img
from nilearn.image import reorder_img

# Got it from Dietrichsen Lab
seg_resamp = resample_to_img("/Volumes/Genf/Atlases/Cerebellum/atl-Anatom_space-MNI_dseg.nii", "/Volumes/Genf/HCP_EP/HCP_EP_rawData/ses-1001/AP_01/regfil_001.nii", interpolation="nearest")
seg_resamp.to_filename("/Volumes/Genf/Atlases/Cerebellum/atl-Anatom_space-MNI_dseg_resampled_to_MNI.nii")

# %% [markdown]
# # ATHENA

# %%
from nilearn.image import resample_to_img
from nilearn.image import reorder_img


seg_resamp = resample_to_img("/Volumes/Genf/Atlases/Cerebellum/atl-Anatom_space-MNI_dseg.nii", "/Volumes/M/ATHENA/concat_fMRI/001_B/MRI/2_Resting_state/run1/func/concat_fMRI.nii.gz", interpolation="nearest")
seg_resamp.to_filename("/Volumes/Genf/Atlases/Cerebellum/Cerebellum_MNI_53x63x52-2mm.nii")

# %% [markdown]
# # Oxford Atlas

# %%
seg_resamp = resample_to_img("/Volumes/Genf/Atlases/Oxford-Cortical-Atlas/fsl/data/atlases/HarvardOxford/HarvardOxford-cortl-maxprob-thr50-2mm-without_background.nii.gz", "/Volumes/M/ATHENA/concat_fMRI/001_B/MRI/2_Resting_state/run1/func/concat_fMRI.nii.gz", interpolation="nearest")
seg_resamp.to_filename("/Volumes/Genf/Atlases/Oxford-Cortical-Atlas/fsl/data/atlases/HarvardOxford/HarvardOxford-cortl-maxprob-thr50-2mm-without_background_resampled_53x63x52.nii.gz")

seg_resamp = resample_to_img("/Volumes/Genf/Atlases/Oxford-Cortical-Atlas/fsl/data/atlases/HarvardOxford/HarvardOxford-sub-maxprob-thr50-2mm-only_subcortical_regions.nii.gz", "/Volumes/M/ATHENA/concat_fMRI/001_B/MRI/2_Resting_state/run1/func/concat_fMRI.nii.gz", interpolation="nearest")
seg_resamp.to_filename("/Volumes/Genf/Atlases/Oxford-Cortical-Atlas/fsl/data/atlases/HarvardOxford/HarvardOxford-sub-maxprob-thr50-2mm-only_subcortical_regions_resampled_53x63x52.nii.gz")
